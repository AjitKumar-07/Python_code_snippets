# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import os

# %%
print(os.listdir())  # checking the file is already here or not
# Out:
# ['.ipynb_checkpoints', 'Data Cleaning using python.ipynb', 'Dataset', 'Pandas_learning.ipynb']

# %%
df=pd.read_csv("C:/Users/Asus/Desktop/Python_code/Dataset/Data.csv")
df
# Out:
#    Index Temprature  Humidity
# 0      0          1       1.0
# 1      1        NaN       NaN
# 2      2          3      31.0
# 3      3          2      22.0
# 4      4          3      33.0
# 5      5          1      11.0
# 6      6          2      21.0
# 7      7        N/a      24.0
# 8      8          1      12.0
# 9      9         na      32.0

# %%
df.isnull().sum()
# Out:
# Index         0
# Temprature    1
# Humidity      1
# dtype: int64

# %% [markdown]
# ### Step1 :- Detecting the null value (Na,N/a,NaN)

# %%
missing_value=["N/a","na",np.nan]  # creating the list of missing values

df=pd.read_csv("C:/Users/Asus/Desktop/Python_code/Dataset/Data.csv",na_values =missing_value)

# %%
df.isnull().sum()
# Out:
# Index         0
# Temprature    3
# Humidity      1
# dtype: int64

# %%
df.isnull().any()
# Out:
# Index         False
# Temprature     True
# Humidity       True
# dtype: bool

# %%
sns.heatmap(df.isnull(),yticklabels=False, annot =True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### step2:- Remove values

# %%
df
# Out:
#    Index  Temprature  Humidity
# 0      0         1.0       1.0
# 1      1         NaN       NaN
# 2      2         3.0      31.0
# 3      3         2.0      22.0
# 4      4         3.0      33.0
# 5      5         1.0      11.0
# 6      6         2.0      21.0
# 7      7         NaN      24.0
# 8      8         1.0      12.0
# 9      9         NaN      32.0

# %%
df.dropna() # All Na values are droped
# Out:
#    Index  Temprature  Humidity
# 0      0         1.0       1.0
# 2      2         3.0      31.0
# 3      3         2.0      22.0
# 4      4         3.0      33.0
# 5      5         1.0      11.0
# 6      6         2.0      21.0
# 8      8         1.0      12.0

# %%
df.dropna(how='all') # it will drop if all values in a single row is null
# here no all values are null in any row so it returns all data.
# Out:
#    Index  Temprature  Humidity
# 0      0         1.0       1.0
# 1      1         NaN       NaN
# 2      2         3.0      31.0
# 3      3         2.0      22.0
# 4      4         3.0      33.0
# 5      5         1.0      11.0
# 6      6         2.0      21.0
# 7      7         NaN      24.0
# 8      8         1.0      12.0
# 9      9         NaN      32.0

# %%
df1= pd.DataFrame(data={
    "Temprature":[1,np.nan,3,2,3],
    "Humidity":[22,np.nan,2,np.nan,22]
})
df1
# Out:
#    Temprature  Humidity
# 0         1.0      22.0
# 1         NaN       NaN
# 2         3.0       2.0
# 3         2.0       NaN
# 4         3.0      22.0

# %%
df1.dropna()
# Out:
#    Temprature  Humidity
# 0         1.0      22.0
# 2         3.0       2.0
# 4         3.0      22.0

# %%
df1.dropna(how='all')
# Out:
#    Temprature  Humidity
# 0         1.0      22.0
# 2         3.0       2.0
# 3         2.0       NaN
# 4         3.0      22.0

# %%
df1
# Out:
#    Temprature  Humidity
# 0         1.0      22.0
# 1         NaN       NaN
# 2         3.0       2.0
# 3         2.0       NaN
# 4         3.0      22.0

# %%
df1.fillna(0) 
# istead of Null values it fills 0 ,
#but it is not good way to fill 0 while data analysis, 
#instead of it fill some values by using forward/backward fill or
# the best way to fill it with Interpolation
# Out:
#    Temprature  Humidity
# 0         1.0      22.0
# 1         0.0       0.0
# 2         3.0       2.0
# 3         2.0       0.0
# 4         3.0      22.0

# %%
df1
# Out:
#    Temprature  Humidity
# 0         1.0      22.0
# 1         NaN       NaN
# 2         3.0       2.0
# 3         2.0       NaN
# 4         3.0      22.0

# %%
df1.fillna(method='ffill')
# Out:
#    Temprature  Humidity
# 0         1.0      22.0
# 1         1.0      22.0
# 2         3.0       2.0
# 3         2.0       2.0
# 4         3.0      22.0

# %%
df1
# Out:
#    Temprature  Humidity
# 0         1.0      22.0
# 1         NaN       NaN
# 2         3.0       2.0
# 3         2.0       NaN
# 4         3.0      22.0

# %%
df1.fillna(method='bfill')
# Out:
#    Temprature  Humidity
# 0         1.0      22.0
# 1         3.0       2.0
# 2         3.0       2.0
# 3         2.0      22.0
# 4         3.0      22.0

# %%
df1
# Out:
#    Temprature  Humidity
# 0         1.0      22.0
# 1         NaN       NaN
# 2         3.0       2.0
# 3         2.0       NaN
# 4         3.0      22.0

# %%
df1.interpolate() # it will take the average value of up and down
# Out:
#    Temprature  Humidity
# 0         1.0      22.0
# 1         2.0      12.0
# 2         3.0       2.0
# 3         2.0      12.0
# 4         3.0      22.0

# %%
df.fillna({
    'Temprature':8888888
})  # substitute by random value
# Out:
#    Index  Temprature  Humidity
# 0      0         1.0       1.0
# 1      1   8888888.0       NaN
# 2      2         3.0      31.0
# 3      3         2.0      22.0
# 4      4         3.0      33.0
# 5      5         1.0      11.0
# 6      6         2.0      21.0
# 7      7   8888888.0      24.0
# 8      8         1.0      12.0
# 9      9   8888888.0      32.0
